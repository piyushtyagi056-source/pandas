# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5] , index = ["a","b","c","d","e"])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"name" : ["piyush","rohan","shubham"],"marks" : [100,53,45]}, index = ["a" , "b","c"])

# %%
df
# Out:
#       name  marks
# a   piyush    100
# b    rohan     53
# c  shubham     45

# %%
df = pd.read_csv("csv.csv", encoding="utf-8")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2024                     Level 1                99999       All industries
# 1  2024                     Level 1                99999       All industries
# 2  2024                     Level 1                99999       All industries
# 3  2024                     Level 1                99999       All industries
# 4  2024                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 55615  Food product manufacturing  Percentage           H37
# 55616  Food product manufacturing  Percentage           H38
# 55617  Food product manufacturing  Percentage           H39
# 55618  Food product manufacturing  Percentage           H40
# 55619  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 55615                          Quick ratio  Financial ratios    52
# 55616  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df.describe()
# Out:
#                Year
# count  55620.000000
# mean    2018.500000
# std        3.452084
# min     2013.000000
# 25%     2015.750000
# 50%     2018.500000
# 75%     2021.250000
# max     2024.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55620 entries, 0 to 55619
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         55620 non-null  int64
#  1   Industry_aggregation_NZSIOC  55620 non-null  object
#  2   Industry_code_NZSIOC         55620 non-null  object
#  3   Industry_name_NZSIOC         55620 non-null  object
#  4   Units                        55620 non-null  object
#  5   Variable_code                55620 non-null  object
#  6   Variable_name                55620 non-null  object
#  7   Variable_category            55620 non-null  object
#  8   Value                        55620 non-null  object
#  9   Industry_code_ANZSIC06       55620 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.2+ MB

# %% [markdown]
# # data selection

# %%
df["Year"]
# Out:
# 0        2024
# 1        2024
# 2        2024
# 3        2024
# 4        2024
#          ...
# 55615    2013
# 55616    2013
# 55617    2013
# 55618    2013
# 55619    2013
# Name: Year, Length: 55620, dtype: int64

# %%
type(df["Year"])
# Out:
# pandas.core.series.Series

# %%
df[["Year","Units"]]
# Out:
#        Year               Units
# 0      2024  Dollars (millions)
# 1      2024  Dollars (millions)
# 2      2024  Dollars (millions)
# 3      2024  Dollars (millions)
# 4      2024  Dollars (millions)
# ...     ...                 ...
# 55615  2013          Percentage
# 55616  2013          Percentage
# 55617  2013          Percentage
# 55618  2013          Percentage
# 55619  2013          Percentage
#
# [55620 rows x 2 columns]

# %%
df.iloc[0] # row not column  used for the iteration
# Out:
# Year                                                                        2024
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H01
# Variable_name                                                       Total income
# Variable_category                                          Financial performance
# Value                                                                     979594
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.read_csv("copy.csv")

# %%
df2.head()
# Out:
#      Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     NaN                     Level 1                99999
# 1  2024.0                     Level 1                99999
# 2  2024.0                     Level 1                  NaN
# 3  2024.0                         NaN                99999
# 4  2024.0                     Level 1                99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                        Variable_name      Variable_category   Value  \
# 0                       Total income  Financial performance  979594
# 1                                NaN  Financial performance  838626
# ...

# %%
df2.dropna()
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 4      2024.0                     Level 1                99999
# 5      2024.0                     Level 1                99999
# 6      2024.0                     Level 1                99999
# 7      2024.0                     Level 1                99999
# 8      2024.0                     Level 1                99999
# ...       ...                         ...                  ...
# 55615  2013.0                     Level 3                 ZZ11
# 55616  2013.0                     Level 3                 ZZ11
# 55617  2013.0                     Level 3                 ZZ11
# 55618  2013.0                     Level 3                 ZZ11
# 55619  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 4                  All industries  Dollars (millions)           H08
# 5                  All industries  Dollars (millions)           H09
# ...

# %%
df2.fillna(0) # inplace = true  is used to chnage the original file which is the cpy . csv
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0         0.0                     Level 1                99999
# 1      2024.0                     Level 1                99999
# 2      2024.0                     Level 1                    0
# 3      2024.0                           0                99999
# 4      2024.0                     Level 1                99999
# ...       ...                         ...                  ...
# 55615  2013.0                     Level 3                 ZZ11
# 55616  2013.0                     Level 3                 ZZ11
# 55617  2013.0                     Level 3                 ZZ11
# 55618  2013.0                     Level 3                 ZZ11
# 55619  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df = pd.read_csv("csv.csv", encoding="utf-8")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.rename(columns={"Units" : "un"}) # if we print the df now it shows the unts no un but if we write the inplace = true and then print the df it shows the un
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC                  un Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55620 entries, 0 to 55619
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         55620 non-null  int64
#  1   Industry_aggregation_NZSIOC  55620 non-null  object
#  2   Industry_code_NZSIOC         55620 non-null  object
#  3   Industry_name_NZSIOC         55620 non-null  object
#  4   Units                        55620 non-null  object
#  5   Variable_code                55620 non-null  object
#  6   Variable_name                55620 non-null  object
#  7   Variable_category            55620 non-null  object
#  8   Value                        55620 non-null  object
#  9   Industry_code_ANZSIC06       55620 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.2+ MB

# %%
df['Year'] = df['Year'].astype(float) # if write str it will show object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55620 entries, 0 to 55619
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         55620 non-null  float64
#  1   Industry_aggregation_NZSIOC  55620 non-null  object
#  2   Industry_code_NZSIOC         55620 non-null  object
#  3   Industry_name_NZSIOC         55620 non-null  object
#  4   Units                        55620 non-null  object
#  5   Variable_code                55620 non-null  object
#  6   Variable_name                55620 non-null  object
#  7   Variable_category            55620 non-null  object
#  8   Value                        55620 non-null  object
#  9   Industry_code_ANZSIC06       55620 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 4.2+ MB

# %%
df['Year'][0]
# Out:
# np.float64(2024.0)

# %%
len(df) # to know the number  of the rows
# Out:
# 55620

# %%
df['zeros'] = [ 0 for i in range(len(df))]

# %%
df
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024.0                     Level 1                99999
# 1      2024.0                     Level 1                99999
# 2      2024.0                     Level 1                99999
# 3      2024.0                     Level 1                99999
# 4      2024.0                     Level 1                99999
# ...       ...                         ...                  ...
# 55615  2013.0                     Level 3                 ZZ11
# 55616  2013.0                     Level 3                 ZZ11
# 55617  2013.0                     Level 3                 ZZ11
# 55618  2013.0                     Level 3                 ZZ11
# 55619  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
def fx(a) :
    return a*a
df['zeros + 1'] = df['Year'].apply(fx)

# %%
df
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024.0                     Level 1                99999
# 1      2024.0                     Level 1                99999
# 2      2024.0                     Level 1                99999
# 3      2024.0                     Level 1                99999
# 4      2024.0                     Level 1                99999
# ...       ...                         ...                  ...
# 55615  2013.0                     Level 3                 ZZ11
# 55616  2013.0                     Level 3                 ZZ11
# 55617  2013.0                     Level 3                 ZZ11
# 55618  2013.0                     Level 3                 ZZ11
# 55619  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.to_csv("export.csv",index=False)

# %%
df1 = pd.DataFrame({
    "name" : [ "piyush","rohan" , "shubham" , "shivam" , "GR" , "aparna" , "khushi"],
    "marks": [100,53,45,3,100,95,3]
})

# %%
df1
# Out:
#       name  marks
# 0   piyush    100
# 1    rohan     53
# 2  shubham     45
# 3   shivam      3
# 4       GR    100
# 5   aparna     95
# 6   khushi      3

# %%
df2 = pd.DataFrame({
    "name" : [ "parul","raj" , "shivangi"],
    "marks": [100,53,45]
})

# %%
df2
# Out:
#        name  marks
# 0     parul    100
# 1       raj     53
# 2  shivangi     45

# %%
pd.concat([df1,df2])
# Out:
#        name  marks
# 0    piyush    100
# 1     rohan     53
# 2   shubham     45
# 3    shivam      3
# 4        GR    100
# 5    aparna     95
# 6    khushi      3
# 0     parul    100
# 1       raj     53
# 2  shivangi     45

# %%
df1 = pd.DataFrame({
    "name" : [ "piyush", "GR" ],
    "marks": [100,100]
})

# %%
df2 = pd.DataFrame({
    "name" : [ "piyush", "GR","harry" ],
    "roll": [1,2,3]
})

# %%
pd.merge(df1,df2) # not include the hrarry data in merge
# Out:
#      name  marks  roll
# 0  piyush    100     1
# 1      GR    100     2

# %%
# Out:
#      name  roll
# 0  piyush     1
# 1      GR     2
# 2   harry     3
